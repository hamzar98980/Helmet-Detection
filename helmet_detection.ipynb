# %%
import zipfile
zip = zipfile.ZipFile("/content/helmet-no-helmet.v1i.yolov11.zip")

# %%
zip.extractall()

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 68.6 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolo11n.pt")

# %%
model.train(data="/content/data.yaml",epochs=15)
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model.save("best.pt")

# %%
trainedModel = YOLO("/content/best.pt")

# %%
pred = trainedModel.predict("/content/2048246-hd_1920_1080_24fps.mp4",save=True)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/447) /content/2048246-hd_1920_1080_24fps.mp4: 384x640 4 helmets, 57.4ms
# video 1/1 (frame 2/447) /content/2048246-hd_1920_1080_24fps.mp4: 384x640 4 helmets, 13.1ms
# video 1/1 (frame 3/447) /content/2048246-hd_1920_1080_24fps.mp4: 384x640 3 helmets, 14.1ms
# video 1/1 (frame 4/447) /content/2048246-hd_1920_1080_24fps.mp4: 384x640 3 helmets, 12.1ms
# ...

# %%
pred = trainedModel.predict("/content/6684690-hd_1920_1080_30fps.mp4",save=True)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/571) /content/6684690-hd_1920_1080_30fps.mp4: 384x640 2 helmets, 9.8ms
# video 1/1 (frame 2/571) /content/6684690-hd_1920_1080_30fps.mp4: 384x640 2 helmets, 11.0ms
# video 1/1 (frame 3/571) /content/6684690-hd_1920_1080_30fps.mp4: 384x640 1 helmet, 24.3ms
# video 1/1 (frame 4/571) /content/6684690-hd_1920_1080_30fps.mp4: 384x640 1 helmet, 14.8ms
# ...
